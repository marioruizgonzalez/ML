# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# Database connection parameters
DB_PARAMS = {
    "dbname": "labasefemenil",
    "user": "marioruiz",
    "password": "welcome1",
    "host": "212.38.95.88",
    "port": "5432"
}

# Equipos string
equipos1 = "América-vs-Guadalajara"
equipo1, equipo2 = equipos1.split("-vs-")

# Query to fetch historical performance data
query = f"""
    SELECT club, SUM(pts) AS total_puntos, SUM(pts2) AS puntos_local, SUM(pts3) AS puntos_visita
    FROM lbf_historical_stats
    WHERE club ILIKE '{equipo1}' OR club ILIKE '{equipo2}'
    GROUP BY club;
"""

# Connect to the PostgreSQL database and execute the query
try:
    with psycopg2.connect(**DB_PARAMS) as conn:
        df = pd.read_sql_query(query, conn)
except Exception as e:
    print(f"Error connecting to the database: {e}")
    exit()

# Check if data is retrieved
if df.empty:
    print("Error: No se encontraron datos con la consulta proporcionada.")
    exit()

# Convertir nombres de equipos a minúsculas para evitar errores en comparación
df["club"] = df["club"].str.lower()

# Asignar valores de cada equipo
equipo1_data = df[df["club"] == equipo1.lower()]
equipo2_data = df[df["club"] == equipo2.lower()]

# Validar si ambos equipos tienen datos
if equipo1_data.empty or equipo2_data.empty:
    print("Error: Faltan datos para uno de los equipos.")
    exit()

# Extraer valores numéricos para el gráfico
labels = ["Total", "Local", "Visita"]
equipo1_values = [equipo1_data["total_puntos"].values[0], equipo1_data["puntos_local"].values[0], equipo1_data["puntos_visita"].values[0]]
equipo2_values = [equipo2_data["total_puntos"].values[0], equipo2_data["puntos_local"].values[0], equipo2_data["puntos_visita"].values[0]]

# Generar el gráfico
x = range(len(labels))

plt.figure(figsize=(10, 6))
plt.bar(x, equipo1_values, width=0.4, label=equipo1.capitalize(), align='center', color='blue')
plt.bar([i + 0.4 for i in x], equipo2_values, width=0.4, label=equipo2.capitalize(), align='center', color='red')

# Formatting
plt.xlabel("Categoría")
plt.ylabel("Puntos Acumulados")
plt.title("Comparación de rendimiento histórico (Total, Local, Visita)")
plt.xticks([i + 0.2 for i in x], labels)
plt.legend()
plt.grid(axis="y")

# Show the plot
plt.show()
# Out:
# C:\Users\ShePlay\AppData\Local\Temp\ipykernel_20560\1286716720.py:29: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# Database connection parameters
DB_PARAMS = {
    "dbname": "labasefemenil",
    "user": "marioruiz",
    "password": "welcome1",
    "host": "212.38.95.88",
    "port": "5432"
}

# Equipos string
equipos1 = "América-vs-Guadalajara"
equipo1, equipo2 = equipos1.split("-vs-")

# Query to fetch historical performance data
query = f"""
    SELECT club, pts2, pts3, jj2, jj3, jg2, jg3, je2, je3, jp2, jp3, gf2, gf3, gc2, gc3, dif2, dif3
    FROM lbf_historical_stats
    WHERE club ILIKE '{equipo1}' OR club ILIKE '{equipo2}';
"""

# Connect to the PostgreSQL database and execute the query
try:
    with psycopg2.connect(**DB_PARAMS) as conn:
        df = pd.read_sql_query(query, conn)
except Exception as e:
    print(f"Error connecting to the database: {e}")
    exit()

# Check if data is retrieved
if df.empty:
    print("Error: No se encontraron datos con la consulta proporcionada.")
    exit()

# Convertir nombres de equipos a minúsculas para evitar errores en comparación
df["club"] = df["club"].str.lower()

# Separar datos por equipo
equipo1_data = df[df["club"] == equipo1.lower()]
equipo2_data = df[df["club"] == equipo2.lower()]

# Validar si ambos equipos tienen datos
if equipo1_data.empty or equipo2_data.empty:
    print("Error: Faltan datos para uno de los equipos.")
    exit()

# Extraer métricas para graficar
labels = ["jj2", "jg2", "je2", "jp2", "gf2", "gc2", "dif2", "jj3", "jg3", "je3", "jp3", "gf3", "gc3", "dif3", "pts3"]
equipo1_values = [equipo1_data[col].values[0] for col in labels]
equipo2_values = [equipo2_data[col].values[0] for col in labels]

# Generar el gráfico
plt.figure(figsize=(10, 6))

# Graficar datos de local (línea sólida)
plt.plot(labels[:7], equipo1_values[:7], marker="o", linestyle="-", color="orange", label=f"{equipo1.lower()} - Local")
plt.plot(labels[:7], equipo2_values[:7], marker="o", linestyle="-", color="brown", label=f"{equipo2.lower()} - Local")

# Graficar datos de visita (línea discontinua)
plt.plot(labels[7:], equipo1_values[7:], marker="s", linestyle="--", color="magenta", label=f"{equipo1.lower()} - Visita")
plt.plot(labels[7:], equipo2_values[7:], marker="s", linestyle="--", color="red", label=f"{equipo2.lower()} - Visita")

# Formato del gráfico
plt.xlabel("Histórico de Rendimiento")
plt.ylabel("Puntos / Desempeño")
plt.title("Comparación de rendimiento histórico (Local vs. Visita)")
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\ShePlay\AppData\Local\Temp\ipykernel_20560\96357779.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
WITH equipos AS (
    SELECT 
        '%america-vs-guadalajara%' AS equipos1,
        '%' || SPLIT_PART('%america-vs-guadalajara%', '-vs-', 2) || '-vs-' || SPLIT_PART('%america-vs-guadalajara%', '-vs-', 1) || '%' AS equipos2,
        REPLACE(SPLIT_PART('%america-vs-guadalajara%', '-vs-', 1), '%', '') AS equipo1,
        REPLACE(SPLIT_PART('%america-vs-guadalajara%', '-vs-', 2), '%', '') AS equipo2
),
goles_equipo1 AS (
    SELECT 
        COALESCE(SUM(goles_local), 0) AS total_goles_local_pair1,
        COALESCE(SUM(goles_visita), 0) AS total_goles_visita_pair1
    FROM (
        SELECT 
            temporada, 
            equipos, 
            marcador, 
            TO_NUMBER(REPLACE(SUBSTR(TRIM(marcador), 1, 1), '-', '0'), '99') AS goles_local,
            TO_NUMBER(REPLACE(SUBSTR(TRIM(marcador), 5, 1), '-', '0'), '99') AS goles_visita
        FROM lbf_partidos_hist, equipos
        WHERE lbf_partidos_hist.equipos LIKE equipos.equipos1
    ) subquery
),
goles_equipo2 AS (
    SELECT 
        COALESCE(SUM(goles_local), 0) AS total_goles_local_pair2,
        COALESCE(SUM(goles_visita), 0) AS total_goles_visita_pair2
    FROM (
        SELECT 
            temporada, 
            equipos, 
            marcador, 
            TO_NUMBER(REPLACE(SUBSTR(TRIM(marcador), 1, 1), '-', '0'), '99') AS goles_local,
            TO_NUMBER(REPLACE(SUBSTR(TRIM(marcador), 5, 1), '-', '0'), '99') AS goles_visita
        FROM lbf_partidos_hist, equipos
        WHERE lbf_partidos_hist.equipos LIKE equipos.equipos2
    ) subquery
)
SELECT 
    e.equipo1,
    e.equipo2,
    g1.total_goles_local_pair1,
    g1.total_goles_visita_pair1,
    g2.total_goles_local_pair2,
    g2.total_goles_visita_pair2,
    (g1.total_goles_local_pair1 + g2.total_goles_visita_pair2) AS total_goles_equipo1,
    (g2.total_goles_local_pair2 + g1.total_goles_visita_pair1) AS total_goles_equipo2
FROM equipos e
CROSS JOIN goles_equipo1 g1
CROSS JOIN goles_equipo2 g2;



WITH equipos AS (
    SELECT 
        REPLACE(SPLIT_PART('%america-vs-guadalajara%', '-vs-', 1), '%', '') AS equipo1,
        REPLACE(SPLIT_PART('%america-vs-guadalajara%', '-vs-', 2), '%', '') AS equipo2
),
puntos_fair_play AS (
    SELECT 
        MIN(total_puntos) AS total_puntos_min,
        MAX(total_puntos) AS total_puntos_max
    FROM lbf_fair_play
),
equipo1_stats AS (
    SELECT 
        equipo1 AS equipo, 
        COALESCE(SUM(total_puntos), 0) AS total_puntos,
        COALESCE(SUM(tarjeta_amarilla), 0) AS tarjetas_amarillas,
        COALESCE(SUM(tarjeta_roja_x_segunda_amarilla + tarjeta_roja_directa), 0) AS tarjetas_rojas
    FROM lbf_fair_play, equipos
    WHERE lbf_fair_play.club ILIKE equipo1
    GROUP BY equipo1
),
equipo2_stats AS (
    SELECT 
        equipo2 AS equipo, 
        COALESCE(SUM(total_puntos), 0) AS total_puntos,
        COALESCE(SUM(tarjeta_amarilla), 0) AS tarjetas_amarillas,
        COALESCE(SUM(tarjeta_roja_x_segunda_amarilla + tarjeta_roja_directa), 0) AS tarjetas_rojas
    FROM lbf_fair_play, equipos
    WHERE lbf_fair_play.club ILIKE equipo2
    GROUP BY equipo2
)
SELECT 
    e1.equipo AS equipo1, e2.equipo AS equipo2,
    pf.total_puntos_min, pf.total_puntos_max,
    e1.total_puntos AS total_puntos_equipo1, e1.tarjetas_amarillas AS tarjetas_amarillas_equipo1, e1.tarjetas_rojas AS tarjetas_rojas_equipo1,
    e2.total_puntos AS total_puntos_equipo2, e2.tarjetas_amarillas AS tarjetas_amarillas_equipo2, e2.tarjetas_rojas AS tarjetas_rojas_equipo2
FROM puntos_fair_play pf
CROSS JOIN equipo1_stats e1
CROSS JOIN equipo2_stats e2;



WITH equipos AS (
    SELECT 
        REPLACE(SPLIT_PART('%América-vs-Guadalajara%', '-vs-', 1), '%', '') AS equipo1,
        REPLACE(SPLIT_PART('%América-vs-Guadalajara%', '-vs-', 2), '%', '') AS equipo2
),
historical_points AS (
    SELECT 
        club, 
        COALESCE(SUM(pts), 0) AS total_puntos_acumulados
    FROM lbf_historical_stats
    WHERE club ILIKE (SELECT equipo1 FROM equipos)
       OR club ILIKE (SELECT equipo2 FROM equipos)
    GROUP BY club
)
SELECT 
    (SELECT equipo1 FROM equipos) AS equipo1,
    (SELECT equipo2 FROM equipos) AS equipo2,
    MAX(CASE WHEN club ILIKE (SELECT equipo1 FROM equipos) THEN total_puntos_acumulados END) AS total_puntos_equipo1,
    MAX(CASE WHEN club ILIKE (SELECT equipo2 FROM equipos) THEN total_puntos_acumulados END) AS total_puntos_equipo2
FROM historical_points;

# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# Database connection parameters
DB_PARAMS = {
    "dbname": "labasefemenil",
    "user": "marioruiz",
    "password": "welcome1",
    "host": "212.38.95.88",
    "port": "5432"
}

# Equipos string
equipos1 = "América-vs-Guadalajara"
equipo1, equipo2 = equipos1.split("-vs-")

# Query to fetch historical performance data
query = f"""
    SELECT club, pts2, pts3, jj2, jj3, jg2, jg3, je2, je3, jp2, jp3, gf2, gf3, gc2, gc3, dif2, dif3
    FROM lbf_historical_stats
    WHERE club ILIKE '{equipo1}' OR club ILIKE '{equipo2}';
"""

# Connect to the PostgreSQL database and execute the query
try:
    with psycopg2.connect(**DB_PARAMS) as conn:
        df = pd.read_sql_query(query, conn)
except Exception as e:
    print(f"Error connecting to the database: {e}")
    exit()

# Check if data is retrieved
if df.empty:
    print("Error: No se encontraron datos con la consulta proporcionada.")
    exit()

# Convertir nombres de equipos a minúsculas para evitar errores en comparación
df["club"] = df["club"].str.lower()

# Separar datos por equipo
equipo1_data = df[df["club"] == equipo1.lower()]
equipo2_data = df[df["club"] == equipo2.lower()]

# Validar si ambos equipos tienen datos
if equipo1_data.empty or equipo2_data.empty:
    print("Error: Faltan datos para uno de los equipos.")
    exit()

# Extraer métricas para graficar
labels = ["juegos jugados local", "jg2", "je2", "jp2", "gf2", "gc2", "dif2", "jj3", "jg3", "je3", "jp3", "gf3", "gc3", "dif3", "pts3"]
equipo1_values = [equipo1_data[col].values[0] for col in labels]
equipo2_values = [equipo2_data[col].values[0] for col in labels]

# Configurar el tema oscuro
plt.style.use("dark_background")

# Generar el gráfico
plt.figure(figsize=(12, 7))

# Graficar datos de local (línea sólida, equipo 1 amarillo, equipo 2 rojo)
plt.plot(labels[:7], equipo1_values[:7], marker="o", linestyle="-", color="#FFD700", linewidth=2, label=f"{equipo1} - Local")
plt.plot(labels[:7], equipo2_values[:7], marker="o", linestyle="-", color="#cd1731", linewidth=2, label=f"{equipo2} - Local")

# Graficar datos de visita (línea discontinua, equipo 1 amarillo, equipo 2 rojo)
plt.plot(labels[7:], equipo1_values[7:], marker="s", linestyle="--", color="#FFD700", linewidth=2, label=f"{equipo1} - Visita")
plt.plot(labels[7:], equipo2_values[7:], marker="s", linestyle="--", color="#cd1731", linewidth=2, label=f"{equipo2} - Visita")

# Formato del gráfico con fondo oscuro y letras blancas
plt.xlabel("Histórico de Rendimiento", color="white", fontsize=12)
plt.ylabel("Puntos / Desempeño", color="white", fontsize=12)
plt.title("Comparación de rendimiento histórico (Local vs. Visita)", color="white", fontsize=14)
plt.legend(facecolor="blue", edgecolor="white", fontsize=11)
plt.xticks(rotation=45, color="white")
plt.yticks(color="white")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="white")

# Mostrar gráfico
plt.show()
# Out:
# C:\Users\ShePlay\AppData\Local\Temp\ipykernel_20560\2727386708.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
