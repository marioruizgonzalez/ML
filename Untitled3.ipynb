# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
import numpy as np
import sympy

# %%
x =  np.linspace(-5,2,100)
y1 = x**3 + 5*x**2 + 10
y2 = 3*x**2+10*x
y3 = 6*x + 10

# %%
fig, ax = plt.subplots()
ax.plot(x, y1, color="blue", label="y(x)")
ax.plot(x, y2, color="red", label="y'(x)")
ax.plot(x, y3, color="green", label="y''(x)")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mpl.use('qt4agg')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1239, in use(backend, force)
#    1196 def use(backend, *, force=True):
#    1197     """
#    1198     Select the backend used for rendering and GUI integration.
#    1199
#    (...)
#    1237
#    1238     """
# -> 1239     name = validate_backend(backend)
#    1240     # don't (prematurely) resolve the "auto" backend setting
#    1241     if rcParams._get_backend_or_none() == name:
#    1242         # Nothing to do if the requested backend is already set
#
# File ~\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:278, in validate_backend(s)
#     275 else:
#     276     msg = (f"'{s}' is not a valid value for backend; supported values are "
#     277            f"{backend_registry.list_all()}")
# --> 278     raise ValueError(msg)
#
# ValueError: 'qt4agg' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template', 'inline', 'module://matplotlib_inline.backend_inline']
